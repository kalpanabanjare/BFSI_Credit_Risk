# %% [markdown]
# # Importing Libries

# %%
# importing numpy
import numpy as np

# importong pandas
import pandas as pd

# importing seaborn
import seaborn as sns

# importing matplot
import matplotlib.pyplot as plt

# importing warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %% [markdown]
# Importing train data set

# %%
main = pd.read_csv("main_loan_base.csv")

# %%
main.head()
# Out:
#   loan_acc_num  customer_name                         customer_address  \
# 0   LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1   LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2   LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3   LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4   LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0  Consumer-Durable        21916           4929.47               3
# 1       Two-Wheeler       121184          10254.50               1
# 2               Car       487036         116183.86               0
# 3       Two-Wheeler        52125          10310.05               5
# 4  Consumer-Durable         8635           1051.25               0
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                0                  3                127             2
# 1                0                  0                156             2
# 2                1                 10                 22             3
# 3                2                  9                 30             2
# 4                1                  3                 62             2
#
#    interest  monthly_emi disbursal_date default_date
# 0      10.1      1012.32     2019-04-14   2020-07-31
# 1      11.8      5693.24     2015-04-14   2016-07-30
# 2      14.6     16788.02     2015-01-10   2015-04-18
# 3       9.6      2395.69     2018-02-07   2018-09-13
# 4       9.6       396.87     2014-12-25   2016-02-20

# %%
main.tail()
# Out:
#       loan_acc_num   customer_name                         customer_address  \
# 49995   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49996   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49997   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49998   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49999   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#          loan_type  loan_amount  collateral_value  cheque_bounces  \
# 49995  Two-Wheeler       222483          43088.19               2
# 49996  Two-Wheeler       104051           8666.54               6
# 49997  Two-Wheeler        51767           4101.24               1
# 49998  Two-Wheeler        77869          10652.77               0
# 49999  Two-Wheeler       241857          59258.17               0
#
#        number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 49995                2                  8                 42             2
# 49996                2                  9                 86             3
# 49997                0                  4                156             2
# 49998                0                  5                 84             2
# 49999                2                  3                 67             1
#
#        interest  monthly_emi disbursal_date default_date
# 49995       9.6     10225.44     2021-02-03   2022-01-24
# 49996      12.6      3485.88     2013-01-12   2014-04-06
# 49997      14.0      2485.48     2016-05-01   2017-02-05
# 49998      14.9      3771.91     2013-08-29   2014-10-01
# 49999      11.6     21443.47     2014-05-19   2014-11-10

# %%
main.shape
# Out:
# (50000, 15)

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_acc_num       50000 non-null  object
#  1   customer_name      50000 non-null  object
#  2   customer_address   50000 non-null  object
#  3   loan_type          50000 non-null  object
#  4   loan_amount        50000 non-null  int64
#  5   collateral_value   50000 non-null  float64
#  6   cheque_bounces     50000 non-null  int64
#  7   number_of_loans    50000 non-null  int64
#  8   missed_repayments  50000 non-null  int64
#  9   vintage_in_months  50000 non-null  int64
#  10  tenure_years       50000 non-null  int64
#  11  interest           50000 non-null  float64
#  12  monthly_emi        50000 non-null  float64
#  13  disbursal_date     50000 non-null  object
#  14  default_date       50000 non-null  object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 5.7+ MB

# %%
main['disbursal_date'] = pd.to_datetime(main['disbursal_date'], infer_datetime_format=True)
main['default_date'] = pd.to_datetime(main['default_date'], infer_datetime_format=True)

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_acc_num       50000 non-null  object
#  1   customer_name      50000 non-null  object
#  2   customer_address   50000 non-null  object
#  3   loan_type          50000 non-null  object
#  4   loan_amount        50000 non-null  int64
#  5   collateral_value   50000 non-null  float64
#  6   cheque_bounces     50000 non-null  int64
#  7   number_of_loans    50000 non-null  int64
#  8   missed_repayments  50000 non-null  int64
#  9   vintage_in_months  50000 non-null  int64
#  10  tenure_years       50000 non-null  int64
#  11  interest           50000 non-null  float64
#  12  monthly_emi        50000 non-null  float64
#  13  disbursal_date     50000 non-null  datetime64[ns]
#  14  default_date       50000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(6), object(4)
# memory usage: 5.7+ MB

# %%
main.describe()
# Out:
#         loan_amount  collateral_value  cheque_bounces  number_of_loans  \
# count  5.000000e+04      50000.000000    50000.000000     50000.000000
# mean   3.816870e+05      57189.733515        1.764740         1.509540
# std    5.037605e+05      93407.376232        1.760175         1.259389
# min    2.000000e+03          0.070000        0.000000         0.000000
# 25%    2.393550e+04       3329.392500        0.000000         0.000000
# 50%    1.926885e+05      19863.105000        1.000000         1.000000
# 75%    4.334075e+05      62313.440000        3.000000         2.000000
# max    1.999992e+06     592545.710000       11.000000         6.000000
#
#        missed_repayments  vintage_in_months  tenure_years      interest  \
# count       50000.000000        50000.00000  50000.000000  50000.000000
# mean            9.808280           80.01584      2.994620     11.484584
# std             7.788007           44.14149      1.415539      2.019853
# min             0.000000           15.00000      1.000000      8.000000
# 25%             4.000000           44.00000      2.000000      9.700000
# 50%             8.000000           78.00000      3.000000     11.500000
# 75%            15.000000          113.00000      4.000000     13.200000
# max            38.000000          258.00000      5.000000     15.000000
#
#          monthly_emi
# count   50000.000000
# mean    16590.946912
# std     26693.294806
# min        42.520000
# 25%      1158.460000
# 50%      6541.350000
# 75%     19436.355000
# max    179521.680000

# %%
monthly = pd.read_csv("monthly_balance_base.csv")

# %%
monthly.head()
# Out:
#   loan_acc_num        date  balance_amount
# 0   LN79307711  2010-03-26      407.343213
# 1   LN79307711  2010-04-25      545.431227
# 2   LN79307711  2010-05-25      861.932145
# 3   LN79307711  2010-06-24      562.082133
# 4   LN79307711  2010-07-24       37.768861

# %%
monthly.tail()
# Out:
#         loan_acc_num        date  balance_amount
# 4002485   LN46546410  2014-08-12    10875.235336
# 4002486   LN46546410  2014-09-11     8479.809099
# 4002487   LN46546410  2014-10-11     9745.974332
# 4002488   LN46546410  2014-11-10     9226.494566
# 4002489   LN46546410  2014-12-10     8851.138461

# %%
monthly.shape
# Out:
# (4002490, 3)

# %%
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002490 entries, 0 to 4002489
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   loan_acc_num    object
#  1   date            object
#  2   balance_amount  float64
# dtypes: float64(1), object(2)
# memory usage: 91.6+ MB

# %%
monthly.describe()
# Out:
#        balance_amount
# count    4.002490e+06
# mean     9.162366e+03
# std      1.931855e+04
# min     -7.035974e+04
# 25%      4.873859e+02
# 50%      2.560146e+03
# 75%      8.791180e+03
# max      4.472208e+05

# %%
repayment = pd.read_csv("repayment_base.csv")

# %%
repayment.head()
# Out:
#   loan_acc_num  repayment_amount repayment_date
# 0   LN79307711       1012.320000     2019-05-18
# 1   LN79307711        667.987539     2019-06-20
# 2   LN79307711       1012.320000     2019-07-16
# 3   LN79307711       1012.320000     2019-08-16
# 4   LN79307711       1012.320000     2019-09-22

# %%
repayment.tail()
# Out:
#        loan_acc_num  repayment_amount repayment_date
# 626596   LN74765572           3771.91     2014-10-22
# 626597   LN74765572           3771.91     2014-11-15
# 626598   LN46546410          21443.47     2014-06-12
# 626599   LN46546410          21443.47     2014-07-18
# 626600   LN46546410          21443.47     2014-08-18

# %%
repayment.shape
# Out:
# (626601, 3)

# %%
repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626601 entries, 0 to 626600
# Data columns (total 3 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   loan_acc_num      626601 non-null  object
#  1   repayment_amount  626601 non-null  float64
#  2   repayment_date    626601 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 14.3+ MB

# %%
repayment['repayment_date'] = pd.to_datetime(repayment['repayment_date'], infer_datetime_format=True)

# %%
repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626601 entries, 0 to 626600
# Data columns (total 3 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   loan_acc_num      626601 non-null  object
#  1   repayment_amount  626601 non-null  float64
#  2   repayment_date    626601 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 14.3+ MB

# %%
repayment.describe()
# Out:
#        repayment_amount
# count     626601.000000
# mean       12080.113187
# std        19862.034048
# min            0.003761
# 25%          742.820000
# 50%         4893.860000
# 75%        13031.560000
# max       179521.680000

# %%
repayment['loan_acc_num'].nunique()
# Out:
# 46008

# %%
repayment = round(repayment.groupby('loan_acc_num')['repayment_amount'].sum(),2)
repayment = pd.DataFrame({"loan_acc_num":repayment.index, "repayment_amount":repayment.values})
repayment.head()
# Out:
#   loan_acc_num  repayment_amount
# 0   LN10000701          40020.99
# 1   LN10001077         112218.47
# 2   LN10004116         290634.94
# 3   LN10007976         337321.72
# 4   LN10010204          61290.49

# %%
#Creating a new data set with zero duplicates.
main = main[~main['loan_acc_num'].duplicated()]
print(main.shape)
# Out:
# (49985, 15)

# %% [markdown]
# Marge the data into one data set

# %%
df = pd.merge(
    left=main,
    right=repayment,
    left_on='loan_acc_num',
    right_on='loan_acc_num',
    how='left'
)

# %%
df.head()
# Out:
#   loan_acc_num  customer_name                         customer_address  \
# 0   LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1   LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2   LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3   LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4   LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0  Consumer-Durable        21916           4929.47               3
# 1       Two-Wheeler       121184          10254.50               1
# 2               Car       487036         116183.86               0
# 3       Two-Wheeler        52125          10310.05               5
# 4  Consumer-Durable         8635           1051.25               0
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                0                  3                127             2
# 1                0                  0                156             2
# 2                1                 10                 22             3
# 3                2                  9                 30             2
# 4                1                  3                 62             2
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount
# 0      10.1      1012.32     2019-04-14   2020-07-31          13572.58
# 1      11.8      5693.24     2015-04-14   2016-07-30          96243.61
# 2      14.6     16788.02     2015-01-10   2015-04-18          74083.73
# 3       9.6      2395.69     2018-02-07   2018-09-13               NaN
# 4       9.6       396.87     2014-12-25   2016-02-20           4462.51

# %%
df.tail()
# Out:
#       loan_acc_num   customer_name                         customer_address  \
# 49980   LN82044693     Urvi Mannan           81\nDey Nagar\nPhagwara-163985
# 49981   LN37968463   Yasmin Tailor      45/573, Kakar Path\nBathinda 988155
# 49982   LN87152445  Kaira Chandran    36/99\nGokhale Circle\nDeoghar 359508
# 49983   LN74765572     Kashvi Toor      69/60\nRege Nagar, New Delhi 735977
# 49984   LN46546410      Hazel Bala  H.No. 723\nSuri Circle, Motihari-467783
#
#          loan_type  loan_amount  collateral_value  cheque_bounces  \
# 49980  Two-Wheeler       222483          43088.19               2
# 49981  Two-Wheeler       104051           8666.54               6
# 49982  Two-Wheeler        51767           4101.24               1
# 49983  Two-Wheeler        77869          10652.77               0
# 49984  Two-Wheeler       241857          59258.17               0
#
#        number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 49980                2                  8                 42             2
# 49981                2                  9                 86             3
# 49982                0                  4                156             2
# 49983                0                  5                 84             2
# 49984                2                  3                 67             1
#
#        interest  monthly_emi disbursal_date default_date  repayment_amount
# 49980       9.6     10225.44     2021-02-03   2022-01-24          30676.32
# 49981      12.6      3485.88     2013-01-12   2014-04-06          38421.07
# 49982      14.0      2485.48     2016-05-01   2017-02-05          43784.34
# 49983      14.9      3771.91     2013-08-29   2014-10-01          52305.66
# 49984      11.6     21443.47     2014-05-19   2014-11-10          64330.41

# %%
df.shape
# Out:
# (49985, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49985 entries, 0 to 49984
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_acc_num       49985 non-null  object
#  1   customer_name      49985 non-null  object
#  2   customer_address   49985 non-null  object
#  3   loan_type          49985 non-null  object
#  4   loan_amount        49985 non-null  int64
#  5   collateral_value   49985 non-null  float64
#  6   cheque_bounces     49985 non-null  int64
#  7   number_of_loans    49985 non-null  int64
#  8   missed_repayments  49985 non-null  int64
#  9   vintage_in_months  49985 non-null  int64
#  10  tenure_years       49985 non-null  int64
#  11  interest           49985 non-null  float64
#  12  monthly_emi        49985 non-null  float64
#  13  disbursal_date     49985 non-null  datetime64[ns]
#  14  default_date       49985 non-null  datetime64[ns]
#  15  repayment_amount   46008 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(6), object(4)
# memory usage: 6.5+ MB

# %%
# deriving target variable
df['target'] = (df['loan_amount']-(df['collateral_value']+df['repayment_amount']))/df['loan_amount']

# %%
df.head()
# Out:
#   loan_acc_num  customer_name                         customer_address  \
# 0   LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1   LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2   LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3   LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4   LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0  Consumer-Durable        21916           4929.47               3
# 1       Two-Wheeler       121184          10254.50               1
# 2               Car       487036         116183.86               0
# 3       Two-Wheeler        52125          10310.05               5
# 4  Consumer-Durable         8635           1051.25               0
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                0                  3                127             2
# 1                0                  0                156             2
# 2                1                 10                 22             3
# 3                2                  9                 30             2
# 4                1                  3                 62             2
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount  \
# 0      10.1      1012.32     2019-04-14   2020-07-31          13572.58
# 1      11.8      5693.24     2015-04-14   2016-07-30          96243.61
# 2      14.6     16788.02     2015-01-10   2015-04-18          74083.73
# 3       9.6      2395.69     2018-02-07   2018-09-13               NaN
# 4       9.6       396.87     2014-12-25   2016-02-20           4462.51
#
#      target
# 0  0.155774
# 1  0.121187
# 2  0.609336
# 3       NaN
# 4  0.361464

# %%
df.isnull().sum()
# Out:
# loan_acc_num            0
# customer_name           0
# customer_address        0
# loan_type               0
# loan_amount             0
# collateral_value        0
# cheque_bounces          0
# number_of_loans         0
# missed_repayments       0
# vintage_in_months       0
# tenure_years            0
# interest                0
# monthly_emi             0
# disbursal_date          0
# default_date            0
# repayment_amount     3977
# target               3977
# dtype: int64

# %%
#null value imputation
df['repayment_amount'] = df['repayment_amount'].fillna(0)

# %%
#null value imputation
df['target'] = df['target'].fillna(df['target'].mean())

# %%
df.isnull().sum()
# Out:
# loan_acc_num         0
# customer_name        0
# customer_address     0
# loan_type            0
# loan_amount          0
# collateral_value     0
# cheque_bounces       0
# number_of_loans      0
# missed_repayments    0
# vintage_in_months    0
# tenure_years         0
# interest             0
# monthly_emi          0
# disbursal_date       0
# default_date         0
# repayment_amount     0
# target               0
# dtype: int64

# %%
#creating new variable: feature engineering
df['due'] = df['loan_amount'] - df['repayment_amount']

# %%
df.head()
# Out:
#   loan_acc_num  customer_name                         customer_address  \
# 0   LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1   LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2   LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3   LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4   LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0  Consumer-Durable        21916           4929.47               3
# 1       Two-Wheeler       121184          10254.50               1
# 2               Car       487036         116183.86               0
# 3       Two-Wheeler        52125          10310.05               5
# 4  Consumer-Durable         8635           1051.25               0
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                0                  3                127             2
# 1                0                  0                156             2
# 2                1                 10                 22             3
# 3                2                  9                 30             2
# 4                1                  3                 62             2
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount  \
# 0      10.1      1012.32     2019-04-14   2020-07-31          13572.58
# 1      11.8      5693.24     2015-04-14   2016-07-30          96243.61
# 2      14.6     16788.02     2015-01-10   2015-04-18          74083.73
# 3       9.6      2395.69     2018-02-07   2018-09-13              0.00
# 4       9.6       396.87     2014-12-25   2016-02-20           4462.51
#
#      target        due
# 0  0.155774    8343.42
# 1  0.121187   24940.39
# 2  0.609336  412952.27
# 3  0.423265   52125.00
# 4  0.361464    4172.49

# %%
monthly.head()
# Out:
#   loan_acc_num        date  balance_amount
# 0   LN79307711  2010-03-26      407.343213
# 1   LN79307711  2010-04-25      545.431227
# 2   LN79307711  2010-05-25      861.932145
# 3   LN79307711  2010-06-24      562.082133
# 4   LN79307711  2010-07-24       37.768861

# %%
monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002490 entries, 0 to 4002489
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   loan_acc_num    object
#  1   date            object
#  2   balance_amount  float64
# dtypes: float64(1), object(2)
# memory usage: 91.6+ MB

# %%
monthly['loan_acc_num'].nunique()
# Out:
# 49671

# %%
monthly = round(monthly.groupby('loan_acc_num')['balance_amount'].mean(),2)
monthly = pd.DataFrame({"loan_acc_num":monthly.index, "average_monthly_balance":monthly.values})
monthly.head()
# Out:
#   loan_acc_num  average_monthly_balance
# 0   LN10000701                  2301.88
# 1   LN10001077                  2296.28
# 2   LN10004116                  8887.38
# 3   LN10007976                  9420.56
# 4   LN10010204                  6446.21

# %%
#Merge the datasets
data = pd.merge(
    left=df,
    right=monthly,
    left_on='loan_acc_num',
    right_on='loan_acc_num',
    how='left'
)

# %%
data.head()
# Out:
#   loan_acc_num  customer_name                         customer_address  \
# 0   LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1   LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2   LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3   LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4   LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0  Consumer-Durable        21916           4929.47               3
# 1       Two-Wheeler       121184          10254.50               1
# 2               Car       487036         116183.86               0
# 3       Two-Wheeler        52125          10310.05               5
# 4  Consumer-Durable         8635           1051.25               0
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                0                  3                127             2
# 1                0                  0                156             2
# 2                1                 10                 22             3
# 3                2                  9                 30             2
# 4                1                  3                 62             2
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount  \
# 0      10.1      1012.32     2019-04-14   2020-07-31          13572.58
# 1      11.8      5693.24     2015-04-14   2016-07-30          96243.61
# 2      14.6     16788.02     2015-01-10   2015-04-18          74083.73
# 3       9.6      2395.69     2018-02-07   2018-09-13              0.00
# 4       9.6       396.87     2014-12-25   2016-02-20           4462.51
#
#      target        due  average_monthly_balance
# 0  0.155774    8343.42                   585.51
# 1  0.121187   24940.39                  7382.03
# 2  0.609336  412952.27                  7812.88
# 3  0.423265   52125.00                   518.08
# 4  0.361464    4172.49                   323.68

# %%
data.shape
# Out:
# (49985, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49985 entries, 0 to 49984
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_acc_num             49985 non-null  object
#  1   customer_name            49985 non-null  object
#  2   customer_address         49985 non-null  object
#  3   loan_type                49985 non-null  object
#  4   loan_amount              49985 non-null  int64
#  5   collateral_value         49985 non-null  float64
#  6   cheque_bounces           49985 non-null  int64
#  7   number_of_loans          49985 non-null  int64
#  8   missed_repayments        49985 non-null  int64
#  9   vintage_in_months        49985 non-null  int64
#  10  tenure_years             49985 non-null  int64
#  11  interest                 49985 non-null  float64
#  12  monthly_emi              49985 non-null  float64
#  13  disbursal_date           49985 non-null  datetime64[ns]
#  14  default_date             49985 non-null  datetime64[ns]
#  15  repayment_amount         49985 non-null  float64
#  16  target                   49985 non-null  float64
#  17  due                      49985 non-null  float64
#  18  average_monthly_balance  49671 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(6), object(4)
# memory usage: 7.6+ MB

# %%
data.isnull().sum()
# Out:
# loan_acc_num                 0
# customer_name                0
# customer_address             0
# loan_type                    0
# loan_amount                  0
# collateral_value             0
# cheque_bounces               0
# number_of_loans              0
# missed_repayments            0
# vintage_in_months            0
# tenure_years                 0
# interest                     0
# monthly_emi                  0
# disbursal_date               0
# default_date                 0
# repayment_amount             0
# target                       0
# due                          0
# average_monthly_balance    314
# dtype: int64

# %%
# null value imputation
data['average_monthly_balance'] = data['average_monthly_balance'].fillna(data['average_monthly_balance'].mean())

# %%
data.isnull().sum()
# Out:
# loan_acc_num               0
# customer_name              0
# customer_address           0
# loan_type                  0
# loan_amount                0
# collateral_value           0
# cheque_bounces             0
# number_of_loans            0
# missed_repayments          0
# vintage_in_months          0
# tenure_years               0
# interest                   0
# monthly_emi                0
# disbursal_date             0
# default_date               0
# repayment_amount           0
# target                     0
# due                        0
# average_monthly_balance    0
# dtype: int64

# %%
data.describe()
# Out:
#         loan_amount  collateral_value  cheque_bounces  number_of_loans  \
# count  4.998500e+04      49985.000000    49985.000000     49985.000000
# mean   3.817142e+05      57195.113444        1.764769         1.509573
# std    5.037769e+05      93412.679667        1.760305         1.259326
# min    2.000000e+03          0.070000        0.000000         0.000000
# 25%    2.393400e+04       3329.430000        0.000000         0.000000
# 50%    1.926920e+05      19866.280000        1.000000         1.000000
# 75%    4.334780e+05      62323.370000        3.000000         2.000000
# max    1.999992e+06     592545.710000       11.000000         6.000000
#
#        missed_repayments  vintage_in_months  tenure_years      interest  \
# count       49985.000000       49985.000000  49985.000000  49985.000000
# mean            9.807482          80.016705      2.994578     11.484611
# std             7.787036          44.141987      1.415455      2.019790
# min             0.000000          15.000000      1.000000      8.000000
# 25%             4.000000          44.000000      2.000000      9.700000
# 50%             8.000000          78.000000      3.000000     11.500000
# 75%            15.000000         113.000000      4.000000     13.200000
# max            38.000000         258.000000      5.000000     15.000000
#
#          monthly_emi  repayment_amount        target           due  \
# count   49985.000000      4.998500e+04  49985.000000  4.998500e+04
# mean    16593.115676      1.514337e+05      0.423265  2.302806e+05
# std     26696.292090      2.554824e+05      0.225701  3.437854e+05
# min        42.520000      0.000000e+00     -5.708000 -8.573322e+04
# 25%      1158.280000      6.761950e+03      0.242430  1.580488e+04
# 50%      6541.020000      4.849626e+04      0.423265  9.599627e+04
# 75%     19438.430000      1.668996e+05      0.600358  2.602902e+05
# max    179521.680000      1.852111e+06      0.898372  1.997948e+06
#
#        average_monthly_balance
# count             49985.000000
# mean               7679.277191
# std               16071.151167
# min                   0.100000
# 25%                 417.980000
# 50%                2186.470000
# 75%                7557.930000
# max              261799.900000

# %%
#dropping the records with negative LGD
data = data.drop(data[data['target']<0].index)

# %%
data.head()
# Out:
#   loan_acc_num  customer_name                         customer_address  \
# 0   LN79307711     Aarna Sura        09/506, Anand Path, Ongole 646592
# 1   LN88987787    Amira Konda      11, Dhaliwal Circle\nRaichur 659460
# 2   LN78096023  Eshani Khosla   H.No. 31\nAtwal Street\nKatihar-037896
# 3   LN56862431     Divij Kala     766, Gulati Marg\nPudukkottai-051396
# 4   LN77262680    Vaibhav Bir  55/73, Sachdev Marg\nDharmavaram-332966
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0  Consumer-Durable        21916           4929.47               3
# 1       Two-Wheeler       121184          10254.50               1
# 2               Car       487036         116183.86               0
# 3       Two-Wheeler        52125          10310.05               5
# 4  Consumer-Durable         8635           1051.25               0
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                0                  3                127             2
# 1                0                  0                156             2
# 2                1                 10                 22             3
# 3                2                  9                 30             2
# 4                1                  3                 62             2
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount  \
# 0      10.1      1012.32     2019-04-14   2020-07-31          13572.58
# 1      11.8      5693.24     2015-04-14   2016-07-30          96243.61
# 2      14.6     16788.02     2015-01-10   2015-04-18          74083.73
# 3       9.6      2395.69     2018-02-07   2018-09-13              0.00
# 4       9.6       396.87     2014-12-25   2016-02-20           4462.51
#
#      target        due  average_monthly_balance
# 0  0.155774    8343.42                   585.51
# 1  0.121187   24940.39                  7382.03
# 2  0.609336  412952.27                  7812.88
# 3  0.423265   52125.00                   518.08
# 4  0.361464    4172.49                   323.68

# %% [markdown]
# Importing test dataset

# %%
test_main = pd.read_csv("test_main_loan_base.csv")

# %%
test_main.head()
# Out:
#   loan_acc_num     customer_name                       customer_address  \
# 0   LN14086568        Jayesh Kar    83/65, Deo Circle\nBhagalpur-852841
# 1   LN37082418     Kaira Chhabra           17\nSule Ganj\nAizawl 491897
# 2   LN42963368  Anahita Bhargava  51/421\nKannan Chowk\nVaranasi-209999
# 3   LN54572294        Myra Samra    22\nSubramanian Marg, Bhilai 850327
# 4   LN65792799       Arhaan Rana      22, Kapoor Road\nJalandhar 667155
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0               Car      1259062          10184.09               3
# 1  Consumer-Durable        21731           2313.21               0
# 2               Car       207660           8308.71               1
# 3       Two-Wheeler       193528          26432.24               4
# 4  Consumer-Durable         5980           1641.66               1
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                1                  5                103             1
# 1                3                 26                 39             5
# 2                2                  0                 63             1
# 3                3                 12                 15             2
# 4                1                  0                152             1
#
#    interest  monthly_emi disbursal_date default_date
# 0      12.1    111925.04     2014-11-23   2015-04-30
# 1      12.2       485.59     2014-01-11   2017-03-11
# 2      13.9     18635.42     2012-10-26   2013-06-23
# 3      12.5      9155.29     2021-10-07   2023-01-19
# 4      14.6       538.62     2020-03-04   2020-10-08

# %%
test_main.tail()
# Out:
#      loan_acc_num   customer_name  \
# 9995   LN25049248     Farhan Jain
# 9996   LN90616761  Priyansh Bandi
# 9997   LN43072538    Miraya Kohli
# 9998   LN37781669      Sahil Vala
# 9999   LN20788592   Anahita Joshi
#
#                                   customer_address         loan_type  \
# 9995             17/120\nKata Street, Jammu 917933          Personal
# 9996  H.No. 73, Garde Street, Visakhapatnam-375389       Two-Wheeler
# 9997               58/547, Din Chowk, Arrah 764302  Consumer-Durable
# 9998              88, Chaudhuri Path\nAlwar 825290  Consumer-Durable
# 9999                 93, Hans Nagar\nRaipur-134710       Two-Wheeler
#
#       loan_amount  collateral_value  cheque_bounces  number_of_loans  \
# 9995       389184         116356.68               1                0
# 9996       153260          23943.10               2                2
# 9997        10696            958.95               0                1
# 9998         8187           1459.41               0                1
# 9999       266393          61533.36               5                3
#
#       missed_repayments  vintage_in_months  tenure_years  interest  \
# 9995                  8                107             4       8.6
# 9996                  6                 60             1      14.0
# 9997                  2                162             4       8.9
# 9998                  5                137             3      14.0
# 9999                 15                 15             3       8.4
#
#       monthly_emi disbursal_date default_date
# 9995      9611.11     2017-11-23   2018-03-31
# 9996     13760.77     2014-10-31   2015-04-13
# 9997       265.66     2019-09-11   2021-06-14
# 9998       279.81     2021-11-21   2024-04-18
# 9999      8397.03     2013-05-21   2015-11-14

# %%
test_main.shape
# Out:
# (10000, 15)

# %%
test_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_acc_num       10000 non-null  object
#  1   customer_name      10000 non-null  object
#  2   customer_address   10000 non-null  object
#  3   loan_type          10000 non-null  object
#  4   loan_amount        10000 non-null  int64
#  5   collateral_value   10000 non-null  float64
#  6   cheque_bounces     10000 non-null  int64
#  7   number_of_loans    10000 non-null  int64
#  8   missed_repayments  10000 non-null  int64
#  9   vintage_in_months  10000 non-null  int64
#  10  tenure_years       10000 non-null  int64
#  11  interest           10000 non-null  float64
#  12  monthly_emi        10000 non-null  float64
#  13  disbursal_date     10000 non-null  object
#  14  default_date       10000 non-null  object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 1.1+ MB

# %%
test_main.describe()
# Out:
#         loan_amount  collateral_value  cheque_bounces  number_of_loans  \
# count  1.000000e+04      10000.000000     10000.00000      10000.00000
# mean   3.825381e+05      57759.914277         1.76000          1.49940
# std    5.005845e+05      93155.252125         1.78312          1.26038
# min    2.009000e+03          1.160000         0.00000          0.00000
# 25%    2.405375e+04       3335.285000         0.00000          0.00000
# 50%    1.960010e+05      20323.325000         1.00000          1.00000
# 75%    4.347512e+05      64152.422500         3.00000          2.00000
# max    1.998735e+06     591419.920000        10.00000          6.00000
#
#        missed_repayments  vintage_in_months  tenure_years      interest  \
# count       10000.000000       10000.000000  10000.000000  10000.000000
# mean            9.716700          80.110200      2.986800     11.513510
# std             7.672374          43.607963      1.414081      2.012314
# min             0.000000          15.000000      1.000000      8.000000
# 25%             4.000000          45.000000      2.000000      9.800000
# 50%             8.000000          79.000000      3.000000     11.500000
# 75%            14.000000         112.000000      4.000000     13.200000
# max            35.000000         235.000000      5.000000     15.000000
#
#          monthly_emi
# count   10000.000000
# mean    16625.746339
# std     26404.679908
# min        45.520000
# 25%      1159.372500
# 50%      6673.340000
# 75%     19561.082500
# max    177491.690000

# %%
test_main['disbursal_date'] = pd.to_datetime(test_main['disbursal_date'], infer_datetime_format=True)
test_main['default_date'] = pd.to_datetime(test_main['default_date'], infer_datetime_format=True)

# %%
test_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_acc_num       10000 non-null  object
#  1   customer_name      10000 non-null  object
#  2   customer_address   10000 non-null  object
#  3   loan_type          10000 non-null  object
#  4   loan_amount        10000 non-null  int64
#  5   collateral_value   10000 non-null  float64
#  6   cheque_bounces     10000 non-null  int64
#  7   number_of_loans    10000 non-null  int64
#  8   missed_repayments  10000 non-null  int64
#  9   vintage_in_months  10000 non-null  int64
#  10  tenure_years       10000 non-null  int64
#  11  interest           10000 non-null  float64
#  12  monthly_emi        10000 non-null  float64
#  13  disbursal_date     10000 non-null  datetime64[ns]
#  14  default_date       10000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(6), object(4)
# memory usage: 1.1+ MB

# %%
#Creating a new data set with zero duplicates.
test_main = test_main[~test_main['loan_acc_num'].duplicated()]
print(test_main.shape)
# Out:
# (9997, 15)

# %%
test_monthly = pd.read_csv("test_monthly_balance_base.csv")

# %%
test_monthly.head()
# Out:
#   loan_acc_num        date  balance_amount
# 0   LN14086568  2006-12-13     9014.212689
# 1   LN14086568  2007-01-12    28129.516540
# 2   LN14086568  2007-02-11    10820.366663
# 3   LN14086568  2007-03-13    32491.477851
# 4   LN14086568  2007-04-12    24982.192310

# %%
test_monthly.tail()
# Out:
#        loan_acc_num        date  balance_amount
# 801402   LN20788592  2015-08-16     1018.532243
# 801403   LN20788592  2015-09-15      817.746710
# 801404   LN20788592  2015-10-15      806.961874
# 801405   LN20788592  2015-11-14      883.821828
# 801406   LN20788592  2015-12-14     1629.953225

# %%
test_monthly.shape
# Out:
# (801407, 3)

# %%
test_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801407 entries, 0 to 801406
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   loan_acc_num    801407 non-null  object
#  1   date            801407 non-null  object
#  2   balance_amount  801407 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 18.3+ MB

# %%
test_monthly.describe()
# Out:
#        balance_amount
# count   801407.000000
# mean      9116.219099
# std      18523.987594
# min     -23093.980957
# 25%        509.732668
# 50%       2655.623157
# 75%       9078.030191
# max     400002.354978

# %%
test_repayment = pd.read_csv("test_repayment_base.csv")

# %%
test_repayment.head()
# Out:
#   loan_acc_num  repayment_amount repayment_date
# 0   LN14086568     111925.040000     2014-12-19
# 1   LN14086568     111925.040000     2015-01-26
# 2   LN14086568     111925.040000     2015-02-21
# 3   LN14086568     111925.040000     2015-03-20
# 4   LN14086568      11590.317813     2015-04-26

# %%
test_repayment.tail()
# Out:
#        loan_acc_num  repayment_amount repayment_date
# 125855   LN37781669            279.81     2023-06-27
# 125856   LN37781669            279.81     2023-07-21
# 125857   LN37781669            279.81     2023-08-26
# 125858   LN37781669            279.81     2023-09-22
# 125859   LN20788592           8397.03     2013-06-20

# %%
test_repayment.shape
# Out:
# (125860, 3)

# %%
test_repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125860 entries, 0 to 125859
# Data columns (total 3 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   loan_acc_num      125860 non-null  object
#  1   repayment_amount  125860 non-null  float64
#  2   repayment_date    125860 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 2.9+ MB

# %%
test_repayment.describe()
# Out:
#        repayment_amount
# count     125860.000000
# mean       12196.910234
# std        19540.035204
# min            0.027190
# 25%          778.960000
# 50%         5032.735404
# 75%        13578.458494
# max       177491.690000

# %%
test_repayment = round(test_repayment.groupby('loan_acc_num')['repayment_amount'].sum(),2)
test_repayment = pd.DataFrame({"loan_acc_num":test_repayment.index, "repayment_amount":test_repayment.values})
test_repayment.head()
# Out:
#   loan_acc_num  repayment_amount
# 0   LN10011015           1725.31
# 1   LN10028091           3560.31
# 2   LN10033713          11582.17
# 3   LN10045654          66181.74
# 4   LN10051605          87664.41

# %% [markdown]
# murge test datasets

# %%
test_df = pd.merge(
    left=test_main,
    right=test_repayment,
    left_on='loan_acc_num',
    right_on='loan_acc_num',
    how='left'
)

# %%
test_df.head()
# Out:
#   loan_acc_num     customer_name                       customer_address  \
# 0   LN14086568        Jayesh Kar    83/65, Deo Circle\nBhagalpur-852841
# 1   LN37082418     Kaira Chhabra           17\nSule Ganj\nAizawl 491897
# 2   LN42963368  Anahita Bhargava  51/421\nKannan Chowk\nVaranasi-209999
# 3   LN54572294        Myra Samra    22\nSubramanian Marg, Bhilai 850327
# 4   LN65792799       Arhaan Rana      22, Kapoor Road\nJalandhar 667155
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0               Car      1259062          10184.09               3
# 1  Consumer-Durable        21731           2313.21               0
# 2               Car       207660           8308.71               1
# 3       Two-Wheeler       193528          26432.24               4
# 4  Consumer-Durable         5980           1641.66               1
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                1                  5                103             1
# 1                3                 26                 39             5
# 2                2                  0                 63             1
# 3                3                 12                 15             2
# 4                1                  0                152             1
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount
# 0      12.1    111925.04     2014-11-23   2015-04-30         675861.05
# 1      12.2       485.59     2014-01-11   2017-03-11           2208.65
# 2      13.9     18635.42     2012-10-26   2013-06-23         111812.52
# 3      12.5      9155.29     2021-10-07   2023-01-19          18310.58
# 4      14.6       538.62     2020-03-04   2020-10-08           3428.64

# %%
test_df.tail()
# Out:
#      loan_acc_num   customer_name  \
# 9992   LN25049248     Farhan Jain
# 9993   LN90616761  Priyansh Bandi
# 9994   LN43072538    Miraya Kohli
# 9995   LN37781669      Sahil Vala
# 9996   LN20788592   Anahita Joshi
#
#                                   customer_address         loan_type  \
# 9992             17/120\nKata Street, Jammu 917933          Personal
# 9993  H.No. 73, Garde Street, Visakhapatnam-375389       Two-Wheeler
# 9994               58/547, Din Chowk, Arrah 764302  Consumer-Durable
# 9995              88, Chaudhuri Path\nAlwar 825290  Consumer-Durable
# 9996                 93, Hans Nagar\nRaipur-134710       Two-Wheeler
#
#       loan_amount  collateral_value  cheque_bounces  number_of_loans  \
# 9992       389184         116356.68               1                0
# 9993       153260          23943.10               2                2
# 9994        10696            958.95               0                1
# 9995         8187           1459.41               0                1
# 9996       266393          61533.36               5                3
#
#       missed_repayments  vintage_in_months  tenure_years  interest  \
# 9992                  8                107             4       8.6
# 9993                  6                 60             1      14.0
# 9994                  2                162             4       8.9
# 9995                  5                137             3      14.0
# 9996                 15                 15             3       8.4
#
#       monthly_emi disbursal_date default_date  repayment_amount
# 9992      9611.11     2017-11-23   2018-03-31         174921.37
# 9993     13760.77     2014-10-31   2015-04-13          13760.77
# 9994       265.66     2019-09-11   2021-06-14           9182.21
# 9995       279.81     2021-11-21   2024-04-18           5281.44
# 9996      8397.03     2013-05-21   2015-11-14           8397.03

# %%
test_df.shape
# Out:
# (9997, 16)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9997 entries, 0 to 9996
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_acc_num       9997 non-null   object
#  1   customer_name      9997 non-null   object
#  2   customer_address   9997 non-null   object
#  3   loan_type          9997 non-null   object
#  4   loan_amount        9997 non-null   int64
#  5   collateral_value   9997 non-null   float64
#  6   cheque_bounces     9997 non-null   int64
#  7   number_of_loans    9997 non-null   int64
#  8   missed_repayments  9997 non-null   int64
#  9   vintage_in_months  9997 non-null   int64
#  10  tenure_years       9997 non-null   int64
#  11  interest           9997 non-null   float64
#  12  monthly_emi        9997 non-null   float64
#  13  disbursal_date     9997 non-null   datetime64[ns]
#  14  default_date       9997 non-null   datetime64[ns]
#  15  repayment_amount   9229 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(6), object(4)
# memory usage: 1.3+ MB

# %%
test_df.isnull().sum()
# Out:
# loan_acc_num           0
# customer_name          0
# customer_address       0
# loan_type              0
# loan_amount            0
# collateral_value       0
# cheque_bounces         0
# number_of_loans        0
# missed_repayments      0
# vintage_in_months      0
# tenure_years           0
# interest               0
# monthly_emi            0
# disbursal_date         0
# default_date           0
# repayment_amount     768
# dtype: int64

# %%
#deriving the target
test_df['target'] = (test_df['loan_amount']-(test_df['collateral_value']+test_df['repayment_amount']))/test_df['loan_amount']

# %%
test_df.head()
# Out:
#   loan_acc_num     customer_name                       customer_address  \
# 0   LN14086568        Jayesh Kar    83/65, Deo Circle\nBhagalpur-852841
# 1   LN37082418     Kaira Chhabra           17\nSule Ganj\nAizawl 491897
# 2   LN42963368  Anahita Bhargava  51/421\nKannan Chowk\nVaranasi-209999
# 3   LN54572294        Myra Samra    22\nSubramanian Marg, Bhilai 850327
# 4   LN65792799       Arhaan Rana      22, Kapoor Road\nJalandhar 667155
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0               Car      1259062          10184.09               3
# 1  Consumer-Durable        21731           2313.21               0
# 2               Car       207660           8308.71               1
# 3       Two-Wheeler       193528          26432.24               4
# 4  Consumer-Durable         5980           1641.66               1
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                1                  5                103             1
# 1                3                 26                 39             5
# 2                2                  0                 63             1
# 3                3                 12                 15             2
# 4                1                  0                152             1
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount  \
# 0      12.1    111925.04     2014-11-23   2015-04-30         675861.05
# 1      12.2       485.59     2014-01-11   2017-03-11           2208.65
# 2      13.9     18635.42     2012-10-26   2013-06-23         111812.52
# 3      12.5      9155.29     2021-10-07   2023-01-19          18310.58
# 4      14.6       538.62     2020-03-04   2020-10-08           3428.64
#
#      target
# 0  0.455114
# 1  0.791917
# 2  0.421549
# 3  0.768804
# 4  0.152124

# %%
test_df.isnull().sum()
# Out:
# loan_acc_num           0
# customer_name          0
# customer_address       0
# loan_type              0
# loan_amount            0
# collateral_value       0
# cheque_bounces         0
# number_of_loans        0
# missed_repayments      0
# vintage_in_months      0
# tenure_years           0
# interest               0
# monthly_emi            0
# disbursal_date         0
# default_date           0
# repayment_amount     768
# target               768
# dtype: int64

# %%
#null value imputation
test_df['repayment_amount'] = test_df['repayment_amount'].fillna(0)

# %%
#null value imputation
test_df['target'] = test_df['target'].fillna(0)

# %%
test_df.isnull().sum()
# Out:
# loan_acc_num         0
# customer_name        0
# customer_address     0
# loan_type            0
# loan_amount          0
# collateral_value     0
# cheque_bounces       0
# number_of_loans      0
# missed_repayments    0
# vintage_in_months    0
# tenure_years         0
# interest             0
# monthly_emi          0
# disbursal_date       0
# default_date         0
# repayment_amount     0
# target               0
# dtype: int64

# %%
#creating new variable: feature engineering
test_df['due'] = test_df['loan_amount'] - test_df['repayment_amount']

# %%
test_df.head()
# Out:
#   loan_acc_num     customer_name                       customer_address  \
# 0   LN14086568        Jayesh Kar    83/65, Deo Circle\nBhagalpur-852841
# 1   LN37082418     Kaira Chhabra           17\nSule Ganj\nAizawl 491897
# 2   LN42963368  Anahita Bhargava  51/421\nKannan Chowk\nVaranasi-209999
# 3   LN54572294        Myra Samra    22\nSubramanian Marg, Bhilai 850327
# 4   LN65792799       Arhaan Rana      22, Kapoor Road\nJalandhar 667155
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0               Car      1259062          10184.09               3
# 1  Consumer-Durable        21731           2313.21               0
# 2               Car       207660           8308.71               1
# 3       Two-Wheeler       193528          26432.24               4
# 4  Consumer-Durable         5980           1641.66               1
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                1                  5                103             1
# 1                3                 26                 39             5
# 2                2                  0                 63             1
# 3                3                 12                 15             2
# 4                1                  0                152             1
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount  \
# 0      12.1    111925.04     2014-11-23   2015-04-30         675861.05
# 1      12.2       485.59     2014-01-11   2017-03-11           2208.65
# 2      13.9     18635.42     2012-10-26   2013-06-23         111812.52
# 3      12.5      9155.29     2021-10-07   2023-01-19          18310.58
# 4      14.6       538.62     2020-03-04   2020-10-08           3428.64
#
#      target        due
# 0  0.455114  583200.95
# 1  0.791917   19522.35
# 2  0.421549   95847.48
# 3  0.768804  175217.42
# 4  0.152124    2551.36

# %%
test_monthly = round(test_monthly.groupby('loan_acc_num')['balance_amount'].mean(),2)
test_monthly = pd.DataFrame({"loan_acc_num":test_monthly.index, "average_monthly_balance":test_monthly.values})
test_monthly.head()
# Out:
#   loan_acc_num  average_monthly_balance
# 0   LN10011015                    25.09
# 1   LN10028091                    62.53
# 2   LN10033713                   182.41
# 3   LN10045654                  1838.35
# 4   LN10051605                  3374.17

# %%
#Merge the datasets
test_data = pd.merge(
    left=test_df,
    right=test_monthly,
    left_on='loan_acc_num',
    right_on='loan_acc_num',
    how='left'
)

# %%
test_data.head()
# Out:
#   loan_acc_num     customer_name                       customer_address  \
# 0   LN14086568        Jayesh Kar    83/65, Deo Circle\nBhagalpur-852841
# 1   LN37082418     Kaira Chhabra           17\nSule Ganj\nAizawl 491897
# 2   LN42963368  Anahita Bhargava  51/421\nKannan Chowk\nVaranasi-209999
# 3   LN54572294        Myra Samra    22\nSubramanian Marg, Bhilai 850327
# 4   LN65792799       Arhaan Rana      22, Kapoor Road\nJalandhar 667155
#
#           loan_type  loan_amount  collateral_value  cheque_bounces  \
# 0               Car      1259062          10184.09               3
# 1  Consumer-Durable        21731           2313.21               0
# 2               Car       207660           8308.71               1
# 3       Two-Wheeler       193528          26432.24               4
# 4  Consumer-Durable         5980           1641.66               1
#
#    number_of_loans  missed_repayments  vintage_in_months  tenure_years  \
# 0                1                  5                103             1
# 1                3                 26                 39             5
# 2                2                  0                 63             1
# 3                3                 12                 15             2
# 4                1                  0                152             1
#
#    interest  monthly_emi disbursal_date default_date  repayment_amount  \
# 0      12.1    111925.04     2014-11-23   2015-04-30         675861.05
# 1      12.2       485.59     2014-01-11   2017-03-11           2208.65
# 2      13.9     18635.42     2012-10-26   2013-06-23         111812.52
# 3      12.5      9155.29     2021-10-07   2023-01-19          18310.58
# 4      14.6       538.62     2020-03-04   2020-10-08           3428.64
#
#      target        due  average_monthly_balance
# 0  0.455114  583200.95                 26560.59
# 1  0.791917   19522.35                    80.71
# 2  0.421549   95847.48                 15501.25
# 3  0.768804  175217.42                  2806.72
# 4  0.152124    2551.36                   673.02

# %%
test_data.shape
# Out:
# (9997, 19)

# %%
test_data.isnull().sum()
# Out:
# loan_acc_num                0
# customer_name               0
# customer_address            0
# loan_type                   0
# loan_amount                 0
# collateral_value            0
# cheque_bounces              0
# number_of_loans             0
# missed_repayments           0
# vintage_in_months           0
# tenure_years                0
# interest                    0
# monthly_emi                 0
# disbursal_date              0
# default_date                0
# repayment_amount            0
# target                      0
# due                         0
# average_monthly_balance    57
# dtype: int64

# %%
# null value imputation
test_data['average_monthly_balance'] = test_data['average_monthly_balance'].fillna(test_data['average_monthly_balance'].mean())

# %%
test_data.isnull().sum()
# Out:
# loan_acc_num               0
# customer_name              0
# customer_address           0
# loan_type                  0
# loan_amount                0
# collateral_value           0
# cheque_bounces             0
# number_of_loans            0
# missed_repayments          0
# vintage_in_months          0
# tenure_years               0
# interest                   0
# monthly_emi                0
# disbursal_date             0
# default_date               0
# repayment_amount           0
# target                     0
# due                        0
# average_monthly_balance    0
# dtype: int64

# %% [markdown]
# #  EDA

# %%
#separating numeric and categorical features
numeric_data = data.select_dtypes(include=[np.number])
categorical_data = data.select_dtypes(exclude=[np.number])

# %%
numeric_data.columns
# Out:
# Index(['loan_amount', 'collateral_value', 'cheque_bounces', 'number_of_loans',
#        'missed_repayments', 'vintage_in_months', 'tenure_years', 'interest',
#        'monthly_emi', 'repayment_amount', 'target', 'due',
#        'average_monthly_balance'],
#       dtype='object')

# %%
categorical_data.columns
# Out:
# Index(['loan_acc_num', 'customer_name', 'customer_address', 'loan_type',
#        'disbursal_date', 'default_date'],
#       dtype='object')

# %%
## Top 10 correlated features
def get_redundant_pairs(df):
    '''get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop=set()
    cols=df.columns
    for i in range (0, df.shape[1]):
        for j in range (0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
            return pairs_to_drop
def get_top_abs_correlations(df, n=10):
    au_corr= df.corr().abs().unstack()
    return au_corr[0:n]
print ('Top Absolute Correlations')
print(get_top_abs_correlations(numeric_data, 10))
# Out:
# Top Absolute Correlations
# loan_amount  loan_amount          1.000000
#              collateral_value     0.809763
#              cheque_bounces       0.001048
#              number_of_loans      0.003185
#              missed_repayments    0.005636
#              vintage_in_months    0.004586
#              tenure_years         0.003322
#              interest             0.003949
#              monthly_emi          0.819133
#              repayment_amount     0.780483
# dtype: float64

# %% [markdown]
# ## Univariate Analysis

# %%
from statistics import mean

# %%
print("Average Monthly EMI: ",round(mean(data['monthly_emi']),2))
print("Average Repayment Amount: ",round(mean(data['repayment_amount']),2))
print("Average Loan Amount: ",round(mean(data['loan_amount']),2))
# Out:
# Average Monthly EMI:  16553.64
# Average Repayment Amount:  150993.26
# Average Loan Amount:  381630.43

# %%
# Univariate Analysis
plt.figure(figsize = [14,6])
data["loan_type"].value_counts().plot.barh(width = .8)
plt.title("Type of Loans", fontdict={"fontsize":15}, pad =20)
plt.show()

# %%
# Checking the % of loan type in the entire dataset
plt.figure(figsize = (5,5))
data.loan_type.value_counts().plot(kind='pie', autopct='%1.2f%%').set_title("Loan Type")
plt.show()

# %%
def Uni_Analysis_Numarical(dataframe, column):
    sns.set(style='darkgrid')
    plt.figure(figsize=(25, 5))
    
    plt.subplot(1, 3, 1)
    sns.boxplot(data=dataframe, x=column, orient='v').set(title='Box Plot')
    
    plt.subplot(1, 3, 2)
    sns.distplot(dataframe[column].dropna()).set(title='Distplot')
    plt.show()

# %%
# Distribution of the numerical features
for i in numeric_data:
    Uni_Analysis_Numarical(data,i)

# %% [markdown]
# - Number to Two wheeler loans are maximum
# - Amount of loan disbursed for Car Loans are maximum

# %%
# Creating Univariate boxplots
df1= ['cheque_bounces','number_of_loans','missed_repayments','tenure_years','monthly_emi']
plt.figure(figsize = (20,200), dpi=150) 
for i in enumerate(df1):  
    plt.subplot(100, 2, i[0]+1) 
    plt.subplots_adjust(hspace=0.75)
    sns.boxplot(x = i[1], data = data)

# %% [markdown]
# - Monthly EMIs have enormous outliers. Though it will not effect our analysis.
# - There are few loan accounts who have missed the repayments more than 30 times.
# - People are taking one loan at a time.
# - The loan tenure is 2-4 years.
# - There are few loan account whose cheque has bounced more than 8 times.

# %%
# Creating Univariate countplots
df2= ['cheque_bounces','number_of_loans','missed_repayments','tenure_years']
plt.figure(figsize = (20,200), dpi=120) 
for i in enumerate(df2):  
    plt.subplot(25, 2, i[0]+1) 
    plt.subplots_adjust(hspace=0.5)
    sns.countplot(x = i[1], data = data)

# %% [markdown]
# - The cheques of over 16000 loan accounts have bounced.
# - There is decreasing trend found on missed repayment of loan amount.
# - Number of people are equal taking one and two loan at a time.

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.scatterplot(x=data.loan_amount,
               y= data.repayment_amount,
               data=data, hue='loan_type')
plt.title('Type of loans', fontdict={'fontsize': 10}, pad=20)
# Out:
# Text(0.5, 1.0, 'Type of loans')

# %%
plt.figure(figsize=[7,5])
sns.set(style='darkgrid')
sns.barplot(x=data.loan_type,y= data.loan_amount)
plt.title('Loan Amount Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize=[7,5])
sns.set(style='darkgrid')
sns.barplot(x=data.loan_type,y= data.repayment_amount)
plt.title('Repayment Amount Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize=[7,5])
sns.set(style='darkgrid')
sns.barplot(x= data.loan_type,y= data.target)
plt.title('Target Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize=[7,5])
sns.set(style='darkgrid')
sns.barplot(x= data.loan_type,y= data.monthly_emi)
plt.title('Monthly EMI Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize=[7,5])
sns.set(style='darkgrid')
sns.barplot(x= data.loan_type,y= data.number_of_loans)
plt.title('Number of Loan Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize=[7,5])
sns.set(style='darkgrid')
sns.barplot(x= data.loan_type,y= data.vintage_in_months)
plt.title('Vintage in Months Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize = [7,5])
sns.set(style='darkgrid')
sns.barplot(x = data.loan_type,y = data.missed_repayments)
plt.title('Missed Repayment Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize = [7,5])
sns.set(style='darkgrid')
sns.barplot(x = data.loan_type, y = data.tenure_years)
plt.title('Tenure Vs Loan Type', fontdict={'fontsize' : 10}, pad=20)
plt.show()

# %%
plt.figure(figsize = [7,5])
sns.set(style='darkgrid')
sns.barplot(x = data.loan_type, y = data.collateral_value)
plt.title('Collateral Value Vs Loan Type', fontdict={'fontsize' : 12}, pad=20)
plt.show()

# %% [markdown]
# - Repayment amount and EMI amount of car loan are way higher than other types of loan.

# %% [markdown]
# ## Data preparation : Variable tranformation, Feature engineering

# %%
plt.figure(figsize=(20,20))
plt.style.use('classic')
data[numeric_data.columns].hist(bins=30, figsize=(24,16))
plt.show()

# %%
numeric_data.columns
# Out:
# Index(['loan_amount', 'collateral_value', 'cheque_bounces', 'number_of_loans',
#        'missed_repayments', 'vintage_in_months', 'tenure_years', 'interest',
#        'monthly_emi', 'repayment_amount', 'target', 'due',
#        'average_monthly_balance'],
#       dtype='object')

# %%
(data['average_monthly_balance']**(1/6)).hist()
# Out:
# <Axes: >

# %%
(data['repayment_amount']**(1/5)).hist()
# Out:
# <Axes: >

# %% [markdown]
# Power transformation is done here for linear regression considering all the independent variables are normally distributed

# %%
data['loan_amount']= data['loan_amount']**(1/5)
data['collateral_value']= data['collateral_value']**(1/5)
data['cheque_bounces']= data['cheque_bounces']**(1/2)
data['missed_repayments']= data['missed_repayments']**(1/2)
data['vintage_in_months']= data['vintage_in_months']**(1/2)
data['monthly_emi']= data['monthly_emi']**(1/6)
data['repayment_amount']= data['repayment_amount']**(1/5)
data['average_monthly_balance']= data['average_monthly_balance']**(1/6)

# %%
test_data['collateral_value'] = test_data['collateral_value']**(1/5)
test_data['cheque_bounces'] = test_data['cheque_bounces']**(1/2)
test_data['missed_repayments'] = test_data['missed_repayments']**(1/2)
test_data['vintage_in_months'] = test_data['vintage_in_months']**(1/2)
test_data['monthly_emi'] = test_data['monthly_emi']**(1/6)
test_data['repayment_amount'] = test_data['repayment_amount']**(1/5)
test_data['average_monthly_balance'] = test_data['average_monthly_balance']**(1/8)

# %% [markdown]
# ## Multivariate Analysis

# %%
# Correlation plot: heatmap
plt.figure(figsize = (25,25))
corr= data.corr()
sns.heatmap(corr, cmap='Greens', annot=True)
# Out:
# <Axes: >

# %%
categorical_data.columns
# Out:
# Index(['loan_acc_num', 'customer_name', 'customer_address', 'loan_type',
#        'disbursal_date', 'default_date'],
#       dtype='object')

# %%
curr_time= pd.to_datetime('now')

# %%
curr_time
# Out:
# Timestamp('2024-04-26 07:58:38.523714')

# %%
# Deriving new feature using date column
data['difference'] = (curr_time-data['default_date'])/np.timedelta64(1, "D")

# %%
# Deriving new feature using date column
test_data['difference'] = (curr_time-test_data['default_date'])/np.timedelta64(1,'D')

# %%
# Dropping unnecessary coloumns for model building
data = data.drop(['disbursal_date', 'default_date', 'loan_acc_num', 'customer_name', 'customer_address'],1)

# %%
data.shape
# Out:
# (49889, 15)

# %%
# Dropping unnecessary coloumns for model building
test_data = test_data.drop(['disbursal_date', 'default_date', 'loan_acc_num', 'customer_name', 'customer_address'],1)

# %%
test_data.shape
# Out:
# (9997, 15)

# %%
# Encoading 
encoded = pd.get_dummies(data['loan_type'], drop_first=True)

# %%
# Encoading 
test_encoded = pd.get_dummies(test_data['loan_type'], drop_first=True)

# %%
data = data.drop(['loan_type'], axis=1)

# %%
data.shape
# Out:
# (49889, 14)

# %%
test_data = test_data.drop(['loan_type'], axis=1)

# %%
test_data.shape
# Out:
# (9997, 14)

# %%
data = pd.concat([data,encoded], axis=1)

# %%
test_data = pd.concat([test_data,test_encoded],axis=1)

# %%
data.shape
# Out:
# (49889, 17)

# %%
test_data.shape
# Out:
# (9997, 17)

# %% [markdown]
# # Model Building

# %%
# import train-test split
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns=['target'])
y = data [['target']]
# Choose any random state
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=100)

# %%
X_train.shape
# Out:
# (34922, 16)

# %%
y_train.shape
# Out:
# (34922, 1)

# %%
X_test.shape
# Out:
# (14967, 16)

# %%
y_test.shape
# Out:
# (14967, 1)

# %%
# importing Scaler
from sklearn.preprocessing import StandardScaler

# %%
# scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
unseen = sc.fit_transform(test_data)

# %% [markdown]
# ## Recursive Feature Elimination (RFE)

# %%
# Importing RFE 
from sklearn.feature_selection import RFE

# %%
# importing LinearRegression
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with output number of variable equal to 10
lm= LinearRegression()
lm.fit(X_train, y_train)
rfe=RFE(lm, n_features_to_select=10)
rfe= rfe.fit(X_train, y_train)

# %%
from sklearn.linear_model import *
from  sklearn import metrics

# %%
# Rsquared on test set
y_pred_lr= rfe.predict(X_test)
metrics.r2_score(y_test, y_pred_lr)
# Out:
# 0.7720174853013938

# %% [markdown]
# Multiple Linear Regression

# %%
# Representing LinearRegression as lr
lm = LinearRegression()
lm.fit(X_train, y_train) 

# Rsquared on test set
y_pred_lr = lm.predict(X_test)
metrics.r2_score(y_test, y_pred_lr)
# Out:
# 0.7776720800784993

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(bootstrap = True, n_estimators = 200, random_state = 100, max_depth=4, max_features = None, min_samples_leaf = 2, min_samples_split = 4)
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, max_features=None, min_samples_leaf=2,
#                       min_samples_split=4, n_estimators=200, random_state=100)

# %%
RandomForestRegressor(max_depth = 4, max_features = None, min_samples_leaf = 2, min_samples_split = 4, n_estimators = 200, random_state = 100)
# Out:
# RandomForestRegressor(max_depth=4, max_features=None, min_samples_leaf=2,
#                       min_samples_split=4, n_estimators=200, random_state=100)

# %%
y_pred_train = rf_regressor.predict(X_train)
print(r2_score(y_train, y_pred_train))
# Out:
# 0.7200597887996327

# %%
y_pred_test = rf_regressor.predict(X_test)
print(r2_score(y_test, y_pred_test))
# Out:
# 0.7159486311751634

# %% [markdown]
# Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Hyperparameters for GradientBoostingRegressor
gbr_params = {'n_estimators': 500,
              'max_depth': 4,
              'min_samples_split': 4,
              'learning_rate': 0.01,
              'loss': 'squared_error'}

# Create an instance of gradient boosting regressor
gbr = GradientBoostingRegressor(**gbr_params)

# Fit the model
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)

# Print Coefficient of determination R^2
print("R squared: %.3f" % gbr.score(X_test, y_test))
# Out:
# R squared: 0.898

# %%
y_pred_train = gbr.predict(X_train)
# Print Coefficient of determination R^2
print("R squared in train set: " ,r2_score(y_train, y_pred_train))
# Out:
# R squared in train set:  0.904364581276417

# %%
y_pred_test = gbr.predict(X_test)
# Print Coefficient of determination R^2
print("R_squared in test set: " ,r2_score(y_test, y_pred_test))
# Out:
# R_squared in test set:  0.8980688442535012

# %%
# plot feature importance
print(gbr.feature_importances_)
plt.bar(range(len(gbr.feature_importances_)), gbr.feature_importances_)
plt.show()
# Out:
# [0.00000000e+00 8.59260684e-03 6.68134068e-03 9.56213283e-02
#  2.28624101e-01 4.58037978e-01 5.65897280e-02 0.00000000e+00
#  2.55835081e-03 1.04413489e-01 3.86042079e-02 2.76869144e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]

# %%
feat_importances = pd.Series(gbr.feature_importances_, index = X.columns)
feat_importances.nlargest(20).plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# XGBoost Regressor

# %%
import xgboost
print(xgboost.__version__)  # This will print the version of xgboost installed
# Out:
# 2.0.3

# %%
from numpy import absolute
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from xgboost import XGBRegressor

# %%
# define model
model = XGBRegressor()
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='r2', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)
print('R_squared: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# R_squared: 0.978 (0.001)

# %%
# evaluate model
scores = cross_val_score(model, X_test, y_test, scoring='r2', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)
print('R_squared: %.3f (%.3f)' % (scores.mean(), scores.std()) )
# Out:
# R_squared: 0.970 (0.003)

# %%
from xgboost import XGBRegressor
# define model
RegModel=XGBRegressor(max_depth=4, learning_rate=0.01, n_estimators=500, objective='reg:linear', booster='gbtree')

# %%
XGB=RegModel.fit(X_train,y_train)
prediction=XGB.predict(X_train)
print("train score: ", r2_score(y_train, prediction))
y_pred_test=XGB.predict(X_test)
print("test score: ", r2_score(y_test, y_pred_test))
# Out:
# train score:  0.9012860485159958
# test score:  0.8944776056551244

# %% [markdown]
# AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_reg = AdaBoostRegressor(n_estimators=500,learning_rate=0.1)
Adaboost=ada_reg.fit(X_train,y_train)
prediction=Adaboost.predict(X_train)
print("train score: ", r2_score(y_train, prediction))
y_pred_test=Adaboost.predict(X_test)
print("test score: ", r2_score(y_test, y_pred_test))
# Out:
# train score:  0.7657174636930963
# test score:  0.7630909741504603

# %% [markdown]
# Model Evaluation Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from xgboost import XGBRegressor
params = { 'max_depth': [3,4,5],
           'learning_rate': [0.01, 0.05, 0.1,0.25,0.5,0.015,1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)

clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='r2', 
                   verbose=1)
clf.fit(X_train, y_train)
print("Best parameters:", clf.best_params_)
# Out:
# Fitting 5 folds for each of 126 candidates, totalling 630 fits

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
# define the model with best resulted parameters
RegModel=XGBRegressor(colsample_bytree= 0.7, max_depth=3, learning_rate=0.5, n_estimators=1000, objective='reg:linear', booster='gbtree')
xgbr = xgb.XGBRegressor(seed = 20)
XGB=RegModel.fit(X_train,y_train)
prediction=XGB.predict(X_train)
print("train score: ", r2_score(y_train, prediction))
y_pred_test=XGB.predict(X_test)
print("test score: ", r2_score(y_test, y_pred_test))
# Out:
# train score:  0.9957375603651885
# test score:  0.9887588286839984

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
# define the model with best resulted parameters
RegModel=XGBRegressor(colsample_bytree= 0.7, max_depth=3, learning_rate=0.5, n_estimators=1000, objective='reg:linear', booster='gbtree')
xgbr = xgb.XGBRegressor(seed = 20)
XGB=RegModel.fit(X_train,y_train)
prediction=XGB.predict(X_train)
print("train score: ", r2_score(y_train, prediction))
y_pred_test=XGB.predict(X_test)
print("test score: ", r2_score(y_test, y_pred_test))
# Out:
# train score:  0.9957375603651885
# test score:  0.9887588286839984

# %% [markdown]
# Prediction on Unseen Data

# %%
data.columns
# Out:
# Index(['loan_amount', 'collateral_value', 'cheque_bounces', 'number_of_loans',
#        'missed_repayments', 'vintage_in_months', 'tenure_years', 'interest',
#        'monthly_emi', 'repayment_amount', 'target', 'due',
#        'average_monthly_balance', 'difference', 'Consumer-Durable', 'Personal',
#        'Two-Wheeler'],
#       dtype='object')

# %%
data.shape
# Out:
# (49889, 17)

# %%
test_data.columns
# Out:
# Index(['loan_amount', 'collateral_value', 'cheque_bounces', 'number_of_loans',
#        'missed_repayments', 'vintage_in_months', 'tenure_years', 'interest',
#        'monthly_emi', 'repayment_amount', 'target', 'due',
#        'average_monthly_balance', 'difference', 'Consumer-Durable', 'Personal',
#        'Two-Wheeler'],
#       dtype='object')

# %%
test_data.shape
# Out:
# (9997, 17)

# %%
test_data = test_data.drop(["target"],1)

# %%
test_data.shape
# Out:
# (9997, 16)

# %%
# Making predictions
final_predictions = XGB.predict(test_data)
final_prediction_series = pd.Series(final_predictions)

# %%
# Combining the results into dataframe
submission_df = pd.DataFrame({'id':test_df['loan_acc_num'].values, 'LGD':final_prediction_series.values})

# %%
submission_df.head()
# Out:
#            id       LGD
# 0  LN14086568  0.285016
# 1  LN37082418  0.292716
# 2  LN42963368  0.314628
# 3  LN54572294  0.301387
# 4  LN65792799  0.299000
